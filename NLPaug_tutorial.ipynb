# %% [markdown]
# <a href="https://colab.research.google.com/github/seawavve/PeekABook/blob/main/NLPaug_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install nlpaug
! pip install transformers
import nlpaug.augmenter.word as naw
# Out:
# ...
#      |████████████████████████████████| 2.3MB 17.4MB/s
# ...
#      |████████████████████████████████| 3.3MB 52.4MB/s
# ...
#      |████████████████████████████████| 901kB 42.1MB/s
# ...
# Original:
# She really liked it and always wore it.
# Augmented Text:
# she really genuinely liked wearing it and always wore it.

# %%
text='She really liked it and always wore it.'
print("Original:")
print(text)
aug = naw.ContextualWordEmbsAug(
    model_path='bert-base-uncased', action="insert")
print("Augmented Text:")
for _ in range(3):  
  augmented_text = aug.augment(text)
  print(augmented_text)
# Out:
# Original:
# She really liked it and always wore it.
# Augmented Text:
# because she really liked it and definitely always wore it.
# she have really liked having it and always wore it.
# until she really liked it and always just wore it.
