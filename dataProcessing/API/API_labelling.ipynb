# %% [markdown]
# <a href="https://colab.research.google.com/github/seawavve/PeekABook/blob/main/dataProcessing/API/API_labelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def score_labelling(data,book):
  data=data.loc[:,['sentence','score']]
  data['label']=None
  for i in range(len(data)):
      if (data.iloc[i,1]>=0) and (data.iloc[i,1]<0.15):
          data.iloc[i,2]=1
      elif (data.iloc[i,1]>=0.15):
          data.iloc[i,2]=2
      else:
          data.iloc[i,2]=0
  data=data.dropna(how='any')
  data.to_csv('./' + book + '_labelled.csv', header=True, index=True)
  display(data)

def main():
    books=['Pinocchio','Junglebook']
    for book in books:
      data=pd.read_csv('./'+book+'_API.csv')
      #display(data)
      score_labelling(data,book)
    return 0

if __name__ == "__main__":
	main()
# Out:
#                                                sentence  score label
# 0     The Project Gutenberg EBook of The Adventures ...    0.0     1
# 1     Collodi--Pseudonym of Carlo Lorenzini This eBo...    0.5     2
# 2     You may copy it, give it away or re-use it und...   -0.3     0
# 3     Collodi--Pseudonym of Carlo Lorenzini Release ...    0.1     1
# 4     Collodi [Pseudonym of Carlo Lorenzini] Transla...    0.0     1
# ...                                                 ...    ...   ...
# 3420  For thirty years, he produced and distributed ...    0.0     1
# 3421  Project Gutenberg-tm eBooks are often created ...   -0.1     0
# 3422             unless a copyright notice is included.   -0.2     0
# 3423  Thus, we do not necessarily keep eBooks in com...   -0.5     0
# 3424  Most people start at our Web site which has th...    0.0     1
#
# [3425 rows x 3 columns]
#                                                sentence  score label
# ...
